# %% [markdown]
# # 그리스 문자(Greek Letter)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\alpha > \beta$', fontdict = {'size': 16})

plt.show()

# %% [markdown]
# # 위 첨자(Superscripts), 아래 첨자(Subscopts)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\alpha^2 > \beta_5$', fontdict = {'size': 16})

plt.show()

# %% [markdown]
# # 분수(Fractions)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\frac{1}{2} + \frac{3}{4} = \frac{5}{4}$', fontdict = {'size': 16})

plt.show()

# %% [markdown]
# # 거듭제곱 근호(Radical Signs)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\sqrt{2} + \sqrt[3]{x} = y$', fontdict = {'size': 16})

plt.show()

# %% [markdown]
# # 엑센트 (Accents)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\acute a, \bar a, \tilde a$', fontdict = {'size': 16})
plt.text(1, 13, r'$\vec a \cdot \vec a = |\vec a|^2$', fontdict = {'size': 16})
plt.text(1, 11, r'$\overline{abc}$', fontdict = {'size': 16})

plt.show()

# %% [markdown]
# # 표준 함수(Standard Functions)와 대형 기호(Big Symbols)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.text(1, 15, r'$\sin () \ \cos (x) \ \tan(x)$', fontdict = {'size': 16})
plt.text(1, 12, r'$\lim_{x\rightarrow} (x^2 - x + 2)$', fontdict = {'size': 16})
plt.text(1, 8, r'$\sum_{n=0}^{10}{(n^2 + n)}$', fontdict = {'size': 16})
plt.show()
